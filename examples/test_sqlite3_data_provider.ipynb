# %% [markdown]
# # Test SQLite3 Data Provider

# %% [markdown]
# ## 1. Import Libraries

# %%
# Standard Packages
import datetime
import json
import logging
import os
import sys
import sqlite3

# Third-Party Packages
import pandas as pd

# Local Packages
sys.path.append("..")
from data_retrieval.data_provider.database.sqlite3_data_provider import SQLite3_DataProvider

# %% [markdown]
# ## 1. Instantiate the SQLite3 Data Provider

# %%
sqlite3_dp = SQLite3_DataProvider(db_file_path="test.db")

# %% [markdown]
# ## 2. Test with the Database

# %%
# Create a user table in the db
sql = """
    CREATE TABLE IF NOT EXISTS users (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        name TEXT NOT NULL,
        age INTEGER,
        email TEXT UNIQUE,
        created_at TIMESTAMP DEFAULT CURRENT_TIMESTAMP
    )
"""
sqlite3_dp.execute(sql=sql)
# Out:
# []

# %%
# Insert data into the table
users_data = [
    ('卡尔文森', 21, '111'),
    ('罗斯福', 33, '22'),
    ('里根', 41, '333')
]

sql = """
    INSERT INTO users (name, age, email) VALUES (?, ?, ?)
"""
sqlite3_dp.execute_many(sql=sql, params_list=users_data)
# Out:
# []

# %%
# Try to query the data from the database
try:
    data = sqlite3_dp.execute(sql="SELECT * FROM users", fetch_mode="all", commit=True)
    print(data)
except sqlite3.OperationalError as e:
    print(f"Error: {e}")
# Out:
# [<sqlite3.Row object at 0x00000298C6D6F8B0>, <sqlite3.Row object at 0x00000298F1331C30>, <sqlite3.Row object at 0x00000298F1331C00>, <sqlite3.Row object at 0x00000298F1331BA0>, <sqlite3.Row object at 0x00000298F1331B70>, <sqlite3.Row object at 0x00000298F1331570>]

# %%
pd.DataFrame([dict(d) for d in data]).set_index("id")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 pd.DataFrame([dict(d) for d in data]).set_index("id")
#
# NameError: name 'pd' is not defined

# %%
list(data[0].keys())
# Out:
# ['id', 'name', 'age', 'email', 'created_at']
